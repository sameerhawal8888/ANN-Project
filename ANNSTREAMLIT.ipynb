# %%
# !streamlit run app.py
# Out:
# ^C

# %%
# !where streamlit
# Out:
# C:\Users\SameerHawal08\anaconda3\Scripts\streamlit.cmd
# C:\Users\SameerHawal08\anaconda3\Scripts\streamlit.exe
# D:\Users\SameerHawal08\anaconda3\Scripts\streamlit.cmd
# D:\Users\SameerHawal08\anaconda3\Scripts\streamlit.exe

# %%
import sys
print(sys.executable)
# Out:
# D:\Users\SameerHawal08\anaconda3\envs\tfenv\python.exe

# %%
import sys
# !{sys.executable} -m streamlit run app.py
# Out:
# D:\Users\SameerHawal08\anaconda3\envs\tfenv\python.exe: No module named streamlit

# %%
# !{sys.executable} -m pip install streamlit
# Out:
# Collecting streamlit
#   Downloading streamlit-1.58.0-py3-none-any.whl.metadata (9.6 kB)
# Collecting altair!=5.4.0,!=5.4.1,<7,>=4.0 (from streamlit)
#   Downloading altair-6.2.2-py3-none-any.whl.metadata (11 kB)
# Collecting blinker<2,>=1.5.0 (from streamlit)
#   Using cached blinker-1.9.0-py3-none-any.whl.metadata (1.6 kB)
# Collecting cachetools<8,>=5.5 (from streamlit)
#   Downloading cachetools-7.1.4-py3-none-any.whl.metadata (5.5 kB)
# Collecting click<9,>=7.0 (from streamlit)
#   Downloading click-8.4.2-py3-none-any.whl.metadata (2.6 kB)
# Collecting gitpython!=3.1.19,<4,>=3.0.7 (from streamlit)
#   Using cached gitpython-3.1.50-py3-none-any.whl.metadata (14 kB)
# Requirement already satisfied: numpy<3,>=1.23 in D:\Users\SameerHawal08\anaconda3\envs\tfenv\Lib\site-packages (from streamlit) (2.4.6)
# Requirement already satisfied: packaging>=20 in D:\Users\SameerHawal08\anaconda3\envs\tfenv\Lib\site-packages (from streamlit) (26.0)
# Requirement already satisfied: pandas<4,>=1.4.0 in D:\Users\SameerHawal08\anaconda3\envs\tfenv\Lib\site-packages (from streamlit) (3.0.4)
# Requirement already satisfied: pillow<13,>=7.1.0 in D:\Users\SameerHawal08\anaconda3\envs\tfenv\Lib\site-packages (from streamlit) (12.2.0)
# Collecting pydeck<1,>=0.8.0b4 (from streamlit)
#   Using cached pydeck-0.9.2-py2.py3-none-any.whl.metadata (4.2 kB)
# Requirement already satisfied: protobuf<8,>=3.20 in D:\Users\SameerHawal08\anaconda3\envs\tfenv\Lib\site-packages (from streamlit) (7.35.1)
# Collecting pyarrow>=7.0 (from streamlit)
#   Downloading pyarrow-24.0.0-cp311-cp311-win_amd64.whl.metadata (3.0 kB)
# Requirement already satisfied: requests<3,>=2.27 in D:\Users\SameerHawal08\anaconda3\envs\tfenv\Lib\site-packages (from streamlit) (2.34.2)
# Collecting tenacity<10,>=8.1.0 (from streamlit)
#   Using cached tenacity-9.1.4-py3-none-any.whl.metadata (1.2 kB)
# Collecting toml<2,>=0.10.1 (from streamlit)
#   Using cached toml-0.10.2-py2.py3-none-any.whl.metadata (7.1 kB)
# Requirement already satisfied: typing-extensions<5,>=4.10.0 in D:\Users\SameerHawal08\anaconda3\envs\tfenv\Lib\site-packages (from streamlit) (4.15.0)
# Collecting starlette>=0.40.0 (from streamlit)
#   Downloading starlette-1.3.1-py3-none-any.whl.metadata (6.4 kB)
# Collecting uvicorn>=0.30.0 (from streamlit)
#   Downloading uvicorn-0.49.0-py3-none-any.whl.metadata (6.7 kB)
# Collecting httptools>=0.6.3 (from streamlit)
#   Downloading httptools-0.8.0-cp311-cp311-win_amd64.whl.metadata (3.7 kB)
# Requirement already satisfied: anyio>=4.0.0 in D:\Users\SameerHawal08\anaconda3\envs\tfenv\Lib\site-packages (from streamlit) (4.14.1)
# Collecting python-multipart>=0.0.10 (from streamlit)
#   Downloading python_multipart-0.0.32-py3-none-any.whl.metadata (2.1 kB)
# Collecting websockets>=12.0.0 (from streamlit)
#   Downloading websockets-16.0-cp311-cp311-win_amd64.whl.metadata (7.0 kB)
# Collecting itsdangerous>=2.1.2 (from streamlit)
#   Using cached itsdangerous-2.2.0-py3-none-any.whl.metadata (1.9 kB)
# Collecting watchdog<7,>=2.1.5 (from streamlit)
#   Using cached watchdog-6.0.0-py3-none-win_amd64.whl.metadata (44 kB)
# Requirement already satisfied: jinja2 in D:\Users\SameerHawal08\anaconda3\envs\tfenv\Lib\site-packages (from altair!=5.4.0,!=5.4.1,<7,>=4.0->streamlit) (3.1.6)
# Requirement already satisfied: jsonschema>=3.0 in D:\Users\SameerHawal08\anaconda3\envs\tfenv\Lib\site-packages (from altair!=5.4.0,!=5.4.1,<7,>=4.0->streamlit) (4.26.0)
# Requirement already satisfied: narwhals>=2.4.0 in D:\Users\SameerHawal08\anaconda3\envs\tfenv\Lib\site-packages (from altair!=5.4.0,!=5.4.1,<7,>=4.0->streamlit) (2.22.1)
# Requirement already satisfied: colorama in D:\Users\SameerHawal08\anaconda3\envs\tfenv\Lib\site-packages (from click<9,>=7.0->streamlit) (0.4.6)
# Collecting gitdb<5,>=4.0.1 (from gitpython!=3.1.19,<4,>=3.0.7->streamlit)
#   Using cached gitdb-4.0.12-py3-none-any.whl.metadata (1.2 kB)
# Collecting smmap<6,>=3.0.1 (from gitdb<5,>=4.0.1->gitpython!=3.1.19,<4,>=3.0.7->streamlit)
#   Using cached smmap-5.0.3-py3-none-any.whl.metadata (4.6 kB)
# Requirement already satisfied: python-dateutil>=2.8.2 in D:\Users\SameerHawal08\anaconda3\envs\tfenv\Lib\site-packages (from pandas<4,>=1.4.0->streamlit) (2.9.0.post0)
# Requirement already satisfied: tzdata in D:\Users\SameerHawal08\anaconda3\envs\tfenv\Lib\site-packages (from pandas<4,>=1.4.0->streamlit) (2026.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in D:\Users\SameerHawal08\anaconda3\envs\tfenv\Lib\site-packages (from requests<3,>=2.27->streamlit) (3.4.7)
# Requirement already satisfied: idna<4,>=2.5 in D:\Users\SameerHawal08\anaconda3\envs\tfenv\Lib\site-packages (from requests<3,>=2.27->streamlit) (3.18)
# Requirement already satisfied: urllib3<3,>=1.26 in D:\Users\SameerHawal08\anaconda3\envs\tfenv\Lib\site-packages (from requests<3,>=2.27->streamlit) (2.7.0)
# Requirement already satisfied: certifi>=2023.5.7 in D:\Users\SameerHawal08\anaconda3\envs\tfenv\Lib\site-packages (from requests<3,>=2.27->streamlit) (2026.6.17)
# Requirement already satisfied: MarkupSafe>=2.0 in D:\Users\SameerHawal08\anaconda3\envs\tfenv\Lib\site-packages (from jinja2->altair!=5.4.0,!=5.4.1,<7,>=4.0->streamlit) (3.0.3)
# Requirement already satisfied: attrs>=22.2.0 in D:\Users\SameerHawal08\anaconda3\envs\tfenv\Lib\site-packages (from jsonschema>=3.0->altair!=5.4.0,!=5.4.1,<7,>=4.0->streamlit) (26.1.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in D:\Users\SameerHawal08\anaconda3\envs\tfenv\Lib\site-packages (from jsonschema>=3.0->altair!=5.4.0,!=5.4.1,<7,>=4.0->streamlit) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in D:\Users\SameerHawal08\anaconda3\envs\tfenv\Lib\site-packages (from jsonschema>=3.0->altair!=5.4.0,!=5.4.1,<7,>=4.0->streamlit) (0.37.0)
# Requirement already satisfied: rpds-py>=0.25.0 in D:\Users\SameerHawal08\anaconda3\envs\tfenv\Lib\site-packages (from jsonschema>=3.0->altair!=5.4.0,!=5.4.1,<7,>=4.0->streamlit) (2026.5.1)
# Requirement already satisfied: six>=1.5 in D:\Users\SameerHawal08\anaconda3\envs\tfenv\Lib\site-packages (from python-dateutil>=2.8.2->pandas<4,>=1.4.0->streamlit) (1.17.0)
# Requirement already satisfied: h11>=0.8 in D:\Users\SameerHawal08\anaconda3\envs\tfenv\Lib\site-packages (from uvicorn>=0.30.0->streamlit) (0.16.0)
# Downloading streamlit-1.58.0-py3-none-any.whl (9.2 MB)
#    ---------------------------------------- 0.0/9.2 MB ? eta -:--:--
#    ------ --------------------------------- 1.6/9.2 MB 12.0 MB/s eta 0:00:01
#    ------------ --------------------------- 2.9/9.2 MB 8.0 MB/s eta 0:00:01
#    ---------------------- ----------------- 5.2/9.2 MB 9.1 MB/s eta 0:00:01
#    ----------------------------- ---------- 6.8/9.2 MB 8.7 MB/s eta 0:00:01
#    -------------------------------------- - 8.9/9.2 MB 8.8 MB/s eta 0:00:01
#    ---------------------------------------- 9.2/9.2 MB 8.2 MB/s  0:00:01
# Downloading altair-6.2.2-py3-none-any.whl (797 kB)
#    ---------------------------------------- 0.0/797.6 kB ? eta -:--:--
#    ---------------------------------------- 797.6/797.6 kB 8.5 MB/s  0:00:00
# Using cached blinker-1.9.0-py3-none-any.whl (8.5 kB)
# Downloading cachetools-7.1.4-py3-none-any.whl (16 kB)
# Downloading click-8.4.2-py3-none-any.whl (119 kB)
# Using cached gitpython-3.1.50-py3-none-any.whl (212 kB)
# Using cached gitdb-4.0.12-py3-none-any.whl (62 kB)
# Using cached pydeck-0.9.2-py2.py3-none-any.whl (11.3 MB)
# Using cached smmap-5.0.3-py3-none-any.whl (24 kB)
# Using cached tenacity-9.1.4-py3-none-any.whl (28 kB)
# Using cached toml-0.10.2-py2.py3-none-any.whl (16 kB)
# Using cached watchdog-6.0.0-py3-none-win_amd64.whl (79 kB)
# Downloading httptools-0.8.0-cp311-cp311-win_amd64.whl (90 kB)
# Using cached itsdangerous-2.2.0-py3-none-any.whl (16 kB)
# Downloading pyarrow-24.0.0-cp311-cp311-win_amd64.whl (27.3 MB)
#    ---------------------------------------- 0.0/27.3 MB ? eta -:--:--
#    -- ------------------------------------- 1.8/27.3 MB 9.1 MB/s eta 0:00:03
#    ----- ---------------------------------- 3.4/27.3 MB 8.0 MB/s eta 0:00:03
#    ------- -------------------------------- 5.0/27.3 MB 7.9 MB/s eta 0:00:03
#    ---------- ----------------------------- 6.8/27.3 MB 8.1 MB/s eta 0:00:03
#    ----------- ---------------------------- 8.1/27.3 MB 7.6 MB/s eta 0:00:03
#    -------------- ------------------------- 10.0/27.3 MB 7.9 MB/s eta 0:00:03
#    ----------------- ---------------------- 11.8/27.3 MB 7.9 MB/s eta 0:00:02
#    ------------------- -------------------- 13.4/27.3 MB 7.9 MB/s eta 0:00:02
#    ---------------------- ----------------- 15.2/27.3 MB 8.0 MB/s eta 0:00:02
#    ------------------------ --------------- 16.8/27.3 MB 7.8 MB/s eta 0:00:02
#    -------------------------- ------------- 18.4/27.3 MB 7.8 MB/s eta 0:00:02
#    ---------------------------- ----------- 19.7/27.3 MB 7.7 MB/s eta 0:00:01
#    ------------------------------ --------- 20.7/27.3 MB 7.4 MB/s eta 0:00:01
#    -------------------------------- ------- 22.0/27.3 MB 7.3 MB/s eta 0:00:01
#    ----------------------------------- ---- 23.9/27.3 MB 7.4 MB/s eta 0:00:01
#    ------------------------------------ --- 25.2/27.3 MB 7.3 MB/s eta 0:00:01
#    ---------------------------------------  27.0/27.3 MB 7.4 MB/s eta 0:00:01
#    ---------------------------------------- 27.3/27.3 MB 7.2 MB/s  0:00:03
# Downloading python_multipart-0.0.32-py3-none-any.whl (30 kB)
# Downloading starlette-1.3.1-py3-none-any.whl (73 kB)
# Downloading uvicorn-0.49.0-py3-none-any.whl (71 kB)
# Downloading websockets-16.0-cp311-cp311-win_amd64.whl (178 kB)
# Installing collected packages: websockets, watchdog, toml, tenacity, smmap, python-multipart, pyarrow, itsdangerous, httptools, click, cachetools, blinker, uvicorn, starlette, pydeck, gitdb, gitpython, altair, streamlit
#
#    ----------------------------------------  0/19 [websockets]
#    ----------------------------------------  0/19 [websockets]
#    ----------------------------------------  0/19 [websockets]
#    -- -------------------------------------  1/19 [watchdog]
#    ------ ---------------------------------  3/19 [tenacity]
#    -------- -------------------------------  4/19 [smmap]
#    ------------ ---------------------------  6/19 [pyarrow]
#    ------------ ---------------------------  6/19 [pyarrow]
#    ------------ ---------------------------  6/19 [pyarrow]
#    ------------ ---------------------------  6/19 [pyarrow]
#    ------------ ---------------------------  6/19 [pyarrow]
#    ------------ ---------------------------  6/19 [pyarrow]
#    ------------ ---------------------------  6/19 [pyarrow]
#    ------------ ---------------------------  6/19 [pyarrow]
#    ------------ ---------------------------  6/19 [pyarrow]
#    ------------ ---------------------------  6/19 [pyarrow]
#    ------------ ---------------------------  6/19 [pyarrow]
#    ------------ ---------------------------  6/19 [pyarrow]
#    ------------ ---------------------------  6/19 [pyarrow]
#    ------------ ---------------------------  6/19 [pyarrow]
#    ------------ ---------------------------  6/19 [pyarrow]
#    ------------ ---------------------------  6/19 [pyarrow]
#    ------------ ---------------------------  6/19 [pyarrow]
#    ------------ ---------------------------  6/19 [pyarrow]
#    ------------ ---------------------------  6/19 [pyarrow]
#    ------------ ---------------------------  6/19 [pyarrow]
#    ---------------- -----------------------  8/19 [httptools]
#    ------------------ ---------------------  9/19 [click]
#    ------------------------- -------------- 12/19 [uvicorn]
#    ------------------------- -------------- 12/19 [uvicorn]
#    --------------------------- ------------ 13/19 [starlette]
#    --------------------------- ------------ 13/19 [starlette]
#    ----------------------------- ---------- 14/19 [pydeck]
#    ----------------------------- ---------- 14/19 [pydeck]
#    ----------------------------- ---------- 14/19 [pydeck]
#    ------------------------------- -------- 15/19 [gitdb]
#    ------------------------------- -------- 15/19 [gitdb]
#    --------------------------------- ------ 16/19 [gitpython]
#    --------------------------------- ------ 16/19 [gitpython]
#    ----------------------------------- ---- 17/19 [altair]
#    ----------------------------------- ---- 17/19 [altair]
#    ----------------------------------- ---- 17/19 [altair]
#    ----------------------------------- ---- 17/19 [altair]
#    ----------------------------------- ---- 17/19 [altair]
#    ------------------------------------- -- 18/19 [streamlit]
#    ------------------------------------- -- 18/19 [streamlit]
#    ------------------------------------- -- 18/19 [streamlit]
#    ------------------------------------- -- 18/19 [streamlit]
#    ------------------------------------- -- 18/19 [streamlit]
#    ------------------------------------- -- 18/19 [streamlit]
#    ------------------------------------- -- 18/19 [streamlit]
#    ------------------------------------- -- 18/19 [streamlit]
#    ------------------------------------- -- 18/19 [streamlit]
#    ------------------------------------- -- 18/19 [streamlit]
#    ------------------------------------- -- 18/19 [streamlit]
#    ------------------------------------- -- 18/19 [streamlit]
#    ------------------------------------- -- 18/19 [streamlit]
#    ------------------------------------- -- 18/19 [streamlit]
#    ------------------------------------- -- 18/19 [streamlit]
#    ------------------------------------- -- 18/19 [streamlit]
#    ------------------------------------- -- 18/19 [streamlit]
#    ------------------------------------- -- 18/19 [streamlit]
#    ------------------------------------- -- 18/19 [streamlit]
#    ------------------------------------- -- 18/19 [streamlit]
#    ---------------------------------------- 19/19 [streamlit]
#
# Successfully installed altair-6.2.2 blinker-1.9.0 cachetools-7.1.4 click-8.4.2 gitdb-4.0.12 gitpython-3.1.50 httptools-0.8.0 itsdangerous-2.2.0 pyarrow-24.0.0 pydeck-0.9.2 python-multipart-0.0.32 smmap-5.0.3 starlette-1.3.1 streamlit-1.58.0 tenacity-9.1.4 toml-0.10.2 uvicorn-0.49.0 watchdog-6.0.0 websockets-16.0
#   WARNING: The script websockets.exe is installed in 'D:\Users\SameerHawal08\anaconda3\envs\tfenv\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The script watchmedo.exe is installed in 'D:\Users\SameerHawal08\anaconda3\envs\tfenv\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The script uvicorn.exe is installed in 'D:\Users\SameerHawal08\anaconda3\envs\tfenv\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The script streamlit.exe is installed in 'D:\Users\SameerHawal08\anaconda3\envs\tfenv\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.

# %%
import sys
# !{sys.executable} -m streamlit run app.py
# Out:
# ^C
